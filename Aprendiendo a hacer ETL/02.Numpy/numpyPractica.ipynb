# %%
import numpy as np
url = 'https://gist.githubusercontent.com/ahcamachod/9be09de793dc3bf1e6c3d98eb4e5b1ef/raw/21b85572693200040e11284ef6dcfc3457ec8e11/citrus.csv'
datos = np.loadtxt(url, delimiter=',', usecols=np.arange(1, 6, 1), skiprows=1)

# %%
datos
# Out:
# array([[  2.96,  86.76, 172.  ,  85.  ,   2.  ],
#        [  3.91,  88.05, 166.  ,  78.  ,   3.  ],
#        [  4.42,  95.17, 156.  ,  81.  ,   2.  ],
#        ...,
#        [ 15.59, 256.5 , 168.  ,  82.  ,  20.  ],
#        [ 15.92, 260.14, 142.  ,  72.  ,  11.  ],
#        [ 16.45, 261.51, 152.  ,  74.  ,   2.  ]])

# %%
datos.T
# Out:
# array([[  2.96,   3.91,   4.42, ...,  15.59,  15.92,  16.45],
#        [ 86.76,  88.05,  95.17, ..., 256.5 , 260.14, 261.51],
#        [172.  , 166.  , 156.  , ..., 168.  , 142.  , 152.  ],
#        [ 85.  ,  78.  ,  81.  , ...,  82.  ,  72.  ,  74.  ],
#        [  2.  ,   3.  ,   2.  , ...,  20.  ,  11.  ,   2.  ]])

# %% [markdown]
# Ha llegado el momento de poner a prueba los conocimientos adquiridos durante la lección. Continuando con el proyecto de las naranjas/toronjas, ahora debes seleccionar parte de los datos. Las columnas que evaluaremos son el diámetro y el peso. Crea arrays específicos para almacenar el diámetro y el peso de la naranja y la toronja. El diámetro está en la columna cero y el peso en la columna uno. Los datos de las naranjas van hasta la fila 4999 y los datos de las toronjas comienzan en la fila 5000 del archivo.

# %%
Naranjas=datos[:5000,:]
Toronjas=datos[5000:,:]
naranjas_Diametro=Naranjas[:,0]
naranjas_Peso=Naranjas[:,1]
toronjas_Diametro=Toronjas[:,0]
toronjas_Peso=Toronjas[:,1]

# %%
import matplotlib.pyplot as plt
plt.plot(naranjas_Diametro, naranjas_Peso)
plt.plot(toronjas_Diametro, toronjas_Peso)

# %%
precio_inmuebles = np.array([10000, 120000, 11000, 200000])
precio_inmuebles_lima = precio_inmuebles
precio_inmuebles[0] = 120000

# %%
precio_inmuebles_lima = np.copy(precio_inmuebles)

# %%
''' cuando usamos el signo igual para copiar el array,
 tenemos un nuevo array que apunta a las mismas ubicaciones en la memoria.
  En cambio, cuando usamos "np.copy()",
 las ubicaciones en la memoria son diferentes. '''
# Out:
# ' cuando usamos el signo igual para copiar el array,\n tenemos un nuevo array que apunta a las mismas ubicaciones en la memoria.\n  En cambio, cuando usamos "np.copy()",\n las ubicaciones en la memoria son diferentes. '

# %%
'''
Ha llegado el momento de poner a prueba los conocimientos adquiridos durante la lección.
 Continuando con el proyecto de las naranjas/toronjas,
ahora debes calcular el coeficiente angular y lineal para la recta de las naranjas y
para la recta de las toronjas.
 Utiliza la fórmula de mínimos cuadrados para encontrar cada uno
'''
# Out:
# '  \nHa llegado el momento de poner a prueba los conocimientos adquiridos durante la lección.\n Continuando con el proyecto de las naranjas/toronjas,\nahora debes calcular el coeficiente angular y lineal para la recta de las naranjas y \npara la recta de las toronjas.\n Utiliza la fórmula de mínimos cuadrados para encontrar cada uno\n'

# %% [markdown]
# $$\alpha = pendiente$$
# $$\beta = interseccion$$
# $$n = observaciones$$
# $$y = precio$$
# $$x = fecha$$
#
#
# La solución para la pendiente es:
#
# $$\alpha = \frac{n \sum xy - \sum x \sum y}{n \sum x^2 - (\sum x)^2} $$
#
# Y para la intersección:
#  $$\beta = \frac{\sum y - \alpha \sum x}{n} $$
#
# Y obtenemos la ecuación de la recta:
#
# $$y = \alpha x + \beta $$

# %%
n=np.size(naranjas_Diametro)
y=naranjas_Peso
x=naranjas_Diametro
m=(n*np.sum(x*y)-np.sum(x)*np.sum(y))/(n*np.sum(x**2)-(np.sum(x)**2))
b=(np.sum(y)-m*(np.sum(x)))/n

# %%
y_regresion=m*x+b

# %%
plt.plot(x,y)
plt.plot(x,y_regresion)

# %% [markdown]
# Ha llegado el momento de poner a prueba los conocimientos adquiridos durante la lección. Continuando con el proyecto de las naranjas/toronjas, ahora debes calcular el coeficiente angular utilizando la generación de números aleatorios

# %% [markdown]
# NUMEROS ALEATORIOS PARA NARANJAS

# %%
norma=np.array([])
np.random.seed(84)
coeficientes_angulares=np.random.uniform(0.1,0.9,100)
for i in range(100):
  norma = np.append(norma, np.linalg.norm(y_regresion - (coeficientes_angulares[i]*x + b)))

# %%
x=toronjas_Diametro
y=toronjas_Peso
n=np.size(x)
m=(n*np.sum(x*y)-np.sum(x)*np.sum(y))/(n*np.sum(x**2)-(np.sum(x)**2))
b=(np.sum(y)-m*(np.sum(x)))/n
y_regresion=m*x+b
plt.plot(x,y)
plt.plot(x,y_regresion)

# %% [markdown]
# NUMEROS ALEATORIOS PARA LAS TORONJAS

# %%
norma=np.array([])
np.random.seed(84)
coeficientes_angulares=np.random.uniform(0.1,0.9,100)
for i in range(100):
  norma = np.append(norma, np.linalg.norm(y_regresion - (coeficientes_angulares[i]*x + b)))
